# %%
import pandas as pd
import numpy as np

# %%
visitantes=pd.read_excel('/content/informe-visitante.xlsx')
visitantes
# Out:
#                    Macroproyecto           Proyecto        Unidad  \
# 0     CONJUNTO CERRADO AMSTERDAM  AMSTERDAM TORRE 1  APTO-01-1303
# 1     CONJUNTO CERRADO AMSTERDAM  AMSTERDAM TORRE 1  APTO-01-1303
# 2     CONJUNTO CERRADO AMSTERDAM  AMSTERDAM TORRE 1  APTO-01-2104
# 3     CONJUNTO CERRADO AMSTERDAM       Sin Proyecto    Sin unidad
# 4     CONJUNTO CERRADO AMSTERDAM  AMSTERDAM TORRE 1  APTO-01-1303
# ...                          ...                ...           ...
# 3072  CONJUNTO CERRADO AMSTERDAM       Sin Proyecto    Sin unidad
# 3073  CONJUNTO CERRADO AMSTERDAM       Sin Proyecto    Sin unidad
# 3074  CONJUNTO CERRADO AMSTERDAM       Sin Proyecto    Sin unidad
# 3075  CONJUNTO CERRADO AMSTERDAM  AMSTERDAM TORRE 1  APTO-01-1303
# 3076  CONJUNTO CERRADO AMSTERDAM       Sin Proyecto    Sin unidad
#
#           Medio Publicitario                            Asesor  \
# 0     Sin Medio Publicitario   DARLYN YUSBEY RUBIANO FERNANDEZ
# ...

# %%
visitantes.tail()
# Out:
#                    Macroproyecto           Proyecto        Unidad  \
# 3072  CONJUNTO CERRADO AMSTERDAM       Sin Proyecto    Sin unidad
# 3073  CONJUNTO CERRADO AMSTERDAM       Sin Proyecto    Sin unidad
# 3074  CONJUNTO CERRADO AMSTERDAM       Sin Proyecto    Sin unidad
# 3075  CONJUNTO CERRADO AMSTERDAM  AMSTERDAM TORRE 1  APTO-01-1303
# 3076  CONJUNTO CERRADO AMSTERDAM       Sin Proyecto    Sin unidad
#
#           Medio Publicitario                           Asesor  \
# 3072        SITIO WEB GALIAS  DARLYN YUSBEY RUBIANO FERNANDEZ
# 3073          Redes Sociales      MANUEL STIVEN MUÑOZ MENDOZA
# 3074          Redes Sociales  MAGDA ROCIO CASTILLO  RODRIGUEZ
# 3075  Sin Medio Publicitario  DARLYN YUSBEY RUBIANO FERNANDEZ
# 3076             Mensaje Sms  MAGDA ROCIO CASTILLO  RODRIGUEZ
#
#                Tipo Lead              Nombre Visitante        Fecha Visita  \
# 3072  Lead Seguimiento 2  Leidy Daniela Mendoza Molina 2024-09-09 04:59:44
# ...

# %%
visitantes.head(10)
# Out:
#                 Macroproyecto           Proyecto        Unidad  \
# 0  CONJUNTO CERRADO AMSTERDAM  AMSTERDAM TORRE 1  APTO-01-1303
# 1  CONJUNTO CERRADO AMSTERDAM  AMSTERDAM TORRE 1  APTO-01-1303
# 2  CONJUNTO CERRADO AMSTERDAM  AMSTERDAM TORRE 1  APTO-01-2104
# 3  CONJUNTO CERRADO AMSTERDAM       Sin Proyecto    Sin unidad
# 4  CONJUNTO CERRADO AMSTERDAM  AMSTERDAM TORRE 1  APTO-01-1303
# 5  CONJUNTO CERRADO AMSTERDAM       Sin Proyecto    Sin unidad
# 6  CONJUNTO CERRADO AMSTERDAM       Sin Proyecto    Sin unidad
# 7  CONJUNTO CERRADO AMSTERDAM       Sin Proyecto    Sin unidad
# 8  CONJUNTO CERRADO AMSTERDAM       Sin Proyecto    Sin unidad
# 9  CONJUNTO CERRADO AMSTERDAM       Sin Proyecto    Sin unidad
#
#        Medio Publicitario                            Asesor  \
# 0  Sin Medio Publicitario   DARLYN YUSBEY RUBIANO FERNANDEZ
# 1  Sin Medio Publicitario   DARLYN YUSBEY RUBIANO FERNANDEZ
# 2                    CHAT       JHONATAN JAIR CASTRO MORENO
# ...

# %%
visitantes.shape
# Out:
# (3077, 15)

# %%
visitantes.index
# Out:
# RangeIndex(start=0, stop=3077, step=1)

# %%
visitantes.columns
# Out:
# Index(['Macroproyecto', 'Proyecto', 'Unidad', 'Medio Publicitario', 'Asesor',
#        'Tipo Lead', 'Nombre Visitante', 'Fecha Visita', 'Identificación',
#        'Celular Visitante', 'Correo Visitante', 'Origen Información', 'Fuente',
#        'Campaña', 'Medio'],
#       dtype='object')

# %%
visitantes.dtypes
# Out:
# Macroproyecto                 object
# Proyecto                      object
# Unidad                        object
# Medio Publicitario            object
# Asesor                        object
# Tipo Lead                     object
# Nombre Visitante              object
# Fecha Visita          datetime64[ns]
# Identificación                object
# Celular Visitante             object
# Correo Visitante              object
# Origen Información            object
# Fuente                        object
# Campaña                       object
# Medio                         object
# dtype: object

# %%
visitantes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3077 entries, 0 to 3076
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Macroproyecto       3077 non-null   object
#  1   Proyecto            3077 non-null   object
#  2   Unidad              3077 non-null   object
#  3   Medio Publicitario  3077 non-null   object
#  4   Asesor              3077 non-null   object
#  5   Tipo Lead           3077 non-null   object
#  6   Nombre Visitante    3072 non-null   object
#  7   Fecha Visita        3077 non-null   datetime64[ns]
#  8   Identificación      232 non-null    object
#  9   Celular Visitante   3065 non-null   object
#  10  Correo Visitante    3077 non-null   object
#  11  Origen Información  3077 non-null   object
#  12  Fuente              2160 non-null   object
#  13  Campaña             2160 non-null   object
#  14  Medio               2173 non-null   object
# ...

# %%
visitantes.describe()
# Out:
#                         Fecha Visita
# count                           3077
# mean   2024-09-22 03:06:00.730581504
# min              2024-09-01 04:59:44
# 25%              2024-09-09 04:59:44
# 50%              2024-09-22 04:59:44
# 75%              2024-10-04 04:59:44
# max              2024-10-15 04:59:44

# %%
len(visitantes)
# Out:
# 3077

# %%
max(visitantes)
# Out:
# 'Unidad'

# %%
type(visitantes)
# Out:
# pandas.core.frame.DataFrame

# %%
round(visitantes)
# Out:
#                    Macroproyecto           Proyecto        Unidad  \
# 0     CONJUNTO CERRADO AMSTERDAM  AMSTERDAM TORRE 1  APTO-01-1303
# 1     CONJUNTO CERRADO AMSTERDAM  AMSTERDAM TORRE 1  APTO-01-1303
# 2     CONJUNTO CERRADO AMSTERDAM  AMSTERDAM TORRE 1  APTO-01-2104
# 3     CONJUNTO CERRADO AMSTERDAM       Sin Proyecto    Sin unidad
# 4     CONJUNTO CERRADO AMSTERDAM  AMSTERDAM TORRE 1  APTO-01-1303
# ...                          ...                ...           ...
# 3072  CONJUNTO CERRADO AMSTERDAM       Sin Proyecto    Sin unidad
# 3073  CONJUNTO CERRADO AMSTERDAM       Sin Proyecto    Sin unidad
# 3074  CONJUNTO CERRADO AMSTERDAM       Sin Proyecto    Sin unidad
# 3075  CONJUNTO CERRADO AMSTERDAM  AMSTERDAM TORRE 1  APTO-01-1303
# 3076  CONJUNTO CERRADO AMSTERDAM       Sin Proyecto    Sin unidad
#
#           Medio Publicitario                            Asesor  \
# 0     Sin Medio Publicitario   DARLYN YUSBEY RUBIANO FERNANDEZ
# ...

# %%
visitantes["Macroproyecto"]
# Out:
# 0       CONJUNTO CERRADO AMSTERDAM
# 1       CONJUNTO CERRADO AMSTERDAM
# 2       CONJUNTO CERRADO AMSTERDAM
# 3       CONJUNTO CERRADO AMSTERDAM
# 4       CONJUNTO CERRADO AMSTERDAM
#                    ...
# 3072    CONJUNTO CERRADO AMSTERDAM
# 3073    CONJUNTO CERRADO AMSTERDAM
# 3074    CONJUNTO CERRADO AMSTERDAM
# 3075    CONJUNTO CERRADO AMSTERDAM
# 3076    CONJUNTO CERRADO AMSTERDAM
# Name: Macroproyecto, Length: 3077, dtype: object

# %%
visitantes["Macroproyecto"].index
# Out:
# RangeIndex(start=0, stop=3077, step=1)
