# %%
#ahora lo que vamos hacer es copiar un data frame en otro lado
#vamos a importar pandas y nunpy
import pandas as pd
import numpy as np
#vamos a traer el archivo de drive
df_jugadores=pd.read_csv("/content/players_20 (1).csv")
df_jugadores.head(5)
#vamos a fijar el nombre corto como el index o Id, para esto usamos el metodo set_index
df_jugadores=df_jugadores.set_index("short_name")
df_jugadores.head(5)
#vamos a traer solo las columnas que necesito, y voy actualizar el dataframe
df_jugadores=df_jugadores[["player_url",	"long_name",	"age",	"dob",	"height_cm",	"weight_kg",	"nationality",	"club"]]
df_jugadores.head(5)
# Out:
#                                                           player_url  \
# short_name
# L. Messi           https://sofifa.com/player/158023/lionel-messi/...
# Cristiano Ronaldo  https://sofifa.com/player/20801/c-ronaldo-dos-...
# Neymar Jr          https://sofifa.com/player/190871/neymar-da-sil...
# J. Oblak           https://sofifa.com/player/200389/jan-oblak/20/...
# E. Hazard          https://sofifa.com/player/183277/eden-hazard/2...
#
#                                              long_name  age         dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini   32  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# Neymar Jr                Neymar da Silva Santos Junior   27  1992-02-05
# J. Oblak                                     Jan Oblak   26  1993-01-07
# E. Hazard                                  Eden Hazard   28  1991-01-07
#
#                    height_cm  weight_kg nationality                 club
# short_name
# ...

# %%
#asi creo una copia sin dependencia, cuando modifico algo en la copia no pasa nada en el original
df_jugadores_1=df_jugadores.copy()

# %%
#voy hacer un cambio en la original y luego lo comparo con la copia
df_jugadores.loc["L. Messi","height_cm"]=92

# %%
df_jugadores.head(1)
# Out:
#                                                    player_url  \
# short_name
# L. Messi    https://sofifa.com/player/158023/lionel-messi/...
#
#                                  long_name  age         dob  height_cm  \
# short_name
# L. Messi    Lionel Andrés Messi Cuccittini   32  1987-06-24         92
#
#             weight_kg nationality          club
# short_name
# L. Messi           72   Argentina  FC Barcelona

# %%
df_jugadores_1.head(1)
# Out:
#                                                    player_url  \
# short_name
# L. Messi    https://sofifa.com/player/158023/lionel-messi/...
#
#                                  long_name  age         dob  height_cm  \
# short_name
# L. Messi    Lionel Andrés Messi Cuccittini   32  1987-06-24        170
#
#             weight_kg nationality          club
# short_name
# L. Messi           72   Argentina  FC Barcelona
