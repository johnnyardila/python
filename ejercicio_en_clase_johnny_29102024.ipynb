# %%
# importar pandas
import pandas as pd
import pandas as pd
import numpy as np

# %%
# Opcional: usa el pd.set_option() para mostrar todas las filas de un dataframe por defecto

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Crear un DataFrame

# %%
# leer el archivo csv "bestsellers with categories" (data sobre los 50 libros más vendidos de Amazon de 2009 a 2019.)
bestsellers=pd.read_csv('/content/drive/MyDrive/bestsellers+with+categories - bestsellers+with+categories.csv')

# %%
bestsellers
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# 2          Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3               George Orwell          4.7    21424      6  2017      Fiction
# 4    National Geographic Kids          4.8     7665     12  2019  Non Fiction
# ..                        ...          ...      ...    ...   ...          ...
# 545               Jeff Kinney          4.9     9413      8  2019      Fiction
# 546               Jen Sincero          4.7    14331      8  2016  Non Fiction
# 547               Jen Sincero          4.7    14331      8  2017  Non Fiction
# 548               Jen Sincero          4.7    14331      8  2018  Non Fiction
# 549               Jen Sincero          4.7    14331      8  2019  Non Fiction
#
# [550 rows x 7 columns]

# %%
# acceder al atributo shape
bestsellers.shape
# Out:
# (550, 7)

# %%
# encontrar el tipo de data de cada columna
bestsellers.dtypes
# Out:
# Name            object
# Author          object
# User Rating    float64
# Reviews          int64
# Price            int64
# Year             int64
# Genre           object
# dtype: object

# %% [markdown]
# # Mostrar un DataFrame

# %%
# mostrar primeras 5 filas de un dataframe
bestsellers.head()
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction

# %%
# encontrar valores estadisticos de un dataframe (mean, std, min, max)
bestsellers.describe()
# Out:
#        User Rating       Reviews       Price         Year
# count   550.000000    550.000000  550.000000   550.000000
# mean      4.618364  11953.281818   13.100000  2014.000000
# std       0.226980  11731.132017   10.842262     3.165156
# min       3.300000     37.000000    0.000000  2009.000000
# 25%       4.500000   4058.000000    7.000000  2011.000000
# 50%       4.700000   8580.000000   11.000000  2014.000000
# 75%       4.800000  17253.250000   16.000000  2017.000000
# max       4.900000  87841.000000  105.000000  2019.000000

# %% [markdown]
# # Agregar una nueva Columna

# %%
# Tu tarea es crear una columna llamada 'Critic Rating' que deberia tener numeros random enteros entre 1 y 4
bestsellers['critic rating']=np.random.randint(1,4, size=550)
# 1.importar numpy y crear 550 numeros random enteros entre 1 y 4
numeros=np.arange(0,550)
# 2.agregar nueva columna 'Critic Rating' al dataframe usando los numeros random creados
bestsellers['critic rating']=numeros
# Obs: Los numeros aleatorios en la columna 'Critic Rating' seran diferentes entre tu solucion y la mia, pero vamos a concetrarnos en el codigo en esta seccion.

# %%
# mostrar 5 primeras filas
bestsellers.head()
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre  \
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction
#
#    critic rating
# 0              0
# 1              1
# 2              2
# 3              3
# 4              4

# %% [markdown]
# # Atributos, Metodos y Funciones Basicas

# %%
# acceder al atributo "columns"
bestsellers.columns
# Out:
# Index(['Name', 'Author', 'User Rating', 'Reviews', 'Price', 'Year', 'Genre',
#        'critic rating'],
#       dtype='object')

# %% [markdown]
# # Seleccionar 2 o Mas Columnas de un Dataframe

# %%
# mover la columna 'Critic Rating' entre las columnas "User Rating" y "Reviews" Luego actualizar el dataframe
bestsellers[['Name', 'Author', 'User Rating', 'critic rating', 'Reviews', 'Price', 'Year', 'Genre']]
# Tip: Copiar y pegar los nombres de columna obtenidos con el atributo "columns" y reordenar los elementos usando [[]]
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  critic rating  Reviews  Price  \
# 0                    JJ Smith          4.7              0    17350      8
# 1                Stephen King          4.6              1     2052     22
# 2          Jordan B. Peterson          4.7              2    18979     15
# 3               George Orwell          4.7              3    21424      6
# 4    National Geographic Kids          4.8              4     7665     12
# ..                        ...          ...            ...      ...    ...
# 545               Jeff Kinney          4.9            545     9413      8
# 546               Jen Sincero          4.7            546    14331      8
# 547               Jen Sincero          4.7            547    14331      8
# 548               Jen Sincero          4.7            548    14331      8
# 549               Jen Sincero          4.7            549    14331      8
#
#      Year        Genre
# 0    2016  Non Fiction
# 1    2011      Fiction
# 2    2018  Non Fiction
# 3    2017      Fiction
# 4    2019  Non Fiction
# ..    ...          ...
# 545  2019      Fiction
# 546  2016  Non Fiction
# 547  2017  Non Fiction
# 548  2018  Non Fiction
# 549  2019  Non Fiction
#
# [550 rows x 8 columns]

# %%
# mostrar 5 primeras filas
bestsellers=bestsellers[['Name', 'Author', 'User Rating', 'critic rating', 'Reviews', 'Price', 'Year', 'Genre']]
bestsellers.head(5)
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  critic rating  Reviews  Price  Year  \
# 0                  JJ Smith          4.7              0    17350      8  2016
# 1              Stephen King          4.6              1     2052     22  2011
# 2        Jordan B. Peterson          4.7              2    18979     15  2018
# 3             George Orwell          4.7              3    21424      6  2017
# 4  National Geographic Kids          4.8              4     7665     12  2019
#
#          Genre
# 0  Non Fiction
# 1      Fiction
# 2  Non Fiction
# 3      Fiction
# 4  Non Fiction

# %% [markdown]
# # Operaciones en Dataframes

# %%
# crear una columna llamada "Average Rating" usando la sigueinte formula: Average Rating = (User Rating + Critic Rating)/2
average_rating=(bestsellers['User Rating']+bestsellers['critic rating'])/2
bestsellers['average_rating']=average_rating
# Out:
# <ipython-input-143-d978ffad4d54>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bestsellers['average_rating']=average_rating

# %%
bestsellers
# usar la funcion "round" para redondear los valores del dataframe a 1 decimal y actualizar el dataframe
bestsellers.round(1)
bestsellers=bestsellers.round(1)
bestsellers
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  critic rating  Reviews  Price  \
# 0                    JJ Smith          4.7              0    17350      8
# 1                Stephen King          4.6              1     2052     22
# 2          Jordan B. Peterson          4.7              2    18979     15
# 3               George Orwell          4.7              3    21424      6
# 4    National Geographic Kids          4.8              4     7665     12
# ..                        ...          ...            ...      ...    ...
# 545               Jeff Kinney          4.9            545     9413      8
# 546               Jen Sincero          4.7            546    14331      8
# 547               Jen Sincero          4.7            547    14331      8
# 548               Jen Sincero          4.7            548    14331      8
# 549               Jen Sincero          4.7            549    14331      8
#
#      Year        Genre  average_rating
# 0    2016  Non Fiction             2.4
# 1    2011      Fiction             2.8
# 2    2018  Non Fiction             3.4
# 3    2017      Fiction             3.8
# 4    2019  Non Fiction             4.4
# ..    ...          ...             ...
# 545  2019      Fiction           275.0
# 546  2016  Non Fiction           275.4
# 547  2017  Non Fiction           275.8
# 548  2018  Non Fiction           276.4
# 549  2019  Non Fiction           276.8
#
# [550 rows x 9 columns]

# %% [markdown]
# # Contar Valores

# %%
# contar elementos en columna "Genre" por categoria y devolver la frecuencia relativa
bestsellers['Genre'].value_counts()
# Out:
# Genre
# Non Fiction    310
# Fiction        240
# Name: count, dtype: int64

# %% [markdown]
# # Renombrar Columnas

# %%
# renombrar columnas "User Rating," "Critic Rating" y "Average Rating" a "UR," "CR" y "AR" Luego actualizar el dataframe con el parametro "inplace"
Nueva_columna=bestsellers.rename(columns={'User Rating': 'UR', 'critic rating': 'CR','average_rating':'AR' })
bestsellers=Nueva_columna
bestsellers
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author   UR   CR  Reviews  Price  Year        Genre  \
# 0                    JJ Smith  4.7    0    17350      8  2016  Non Fiction
# 1                Stephen King  4.6    1     2052     22  2011      Fiction
# 2          Jordan B. Peterson  4.7    2    18979     15  2018  Non Fiction
# 3               George Orwell  4.7    3    21424      6  2017      Fiction
# 4    National Geographic Kids  4.8    4     7665     12  2019  Non Fiction
# ..                        ...  ...  ...      ...    ...   ...          ...
# 545               Jeff Kinney  4.9  545     9413      8  2019      Fiction
# 546               Jen Sincero  4.7  546    14331      8  2016  Non Fiction
# 547               Jen Sincero  4.7  547    14331      8  2017  Non Fiction
# 548               Jen Sincero  4.7  548    14331      8  2018  Non Fiction
# 549               Jen Sincero  4.7  549    14331      8  2019  Non Fiction
#
#         AR
# 0      2.4
# 1      2.8
# 2      3.4
# 3      3.8
# 4      4.4
# ..     ...
# 545  275.0
# 546  275.4
# 547  275.8
# 548  276.4
# 549  276.8
#
# [550 rows x 9 columns]

# %%
# mostrar 5 primeras filas
bestsellers.head(5)
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author   UR  CR  Reviews  Price  Year        Genre   AR
# 0                  JJ Smith  4.7   0    17350      8  2016  Non Fiction  2.4
# 1              Stephen King  4.6   1     2052     22  2011      Fiction  2.8
# 2        Jordan B. Peterson  4.7   2    18979     15  2018  Non Fiction  3.4
# 3             George Orwell  4.7   3    21424      6  2017      Fiction  3.8
# 4  National Geographic Kids  4.8   4     7665     12  2019  Non Fiction  4.4

# %%
# seleccionar solo columnas "Name", "Author", "UR", "CR", "AR" y "Year" y actualizar el dataframe
bestsellers[['Name','Author','UR','CR','AR','Year']]
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author   UR   CR     AR  Year
# 0                    JJ Smith  4.7    0    2.4  2016
# 1                Stephen King  4.6    1    2.8  2011
# 2          Jordan B. Peterson  4.7    2    3.4  2018
# 3               George Orwell  4.7    3    3.8  2017
# 4    National Geographic Kids  4.8    4    4.4  2019
# ..                        ...  ...  ...    ...   ...
# 545               Jeff Kinney  4.9  545  275.0  2019
# 546               Jen Sincero  4.7  546  275.4  2016
# 547               Jen Sincero  4.7  547  275.8  2017
# 548               Jen Sincero  4.7  548  276.4  2018
# 549               Jen Sincero  4.7  549  276.8  2019
#
# [550 rows x 6 columns]

# %% [markdown]
# # Ordenar el dataframe

# %%
# ordenar el dataframe en forma descendente segun las columnas "UR" y "CR"
bestsellers.sort_values(['UR','CR'],ascending=False)
# Out:
#                                                   Name                 Author  \
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)            Jeff Kinney
# 521                             Unfreedom of the Press          Mark R. Levin
# 489                   The Wonderful Things You Will Be  Emily Winfield Martin
# 488                   The Wonderful Things You Will Be  Emily Winfield Martin
# 487                   The Wonderful Things You Will Be  Emily Winfield Martin
# ..                                                 ...                    ...
# 22                                           Allegiant          Veronica Roth
# 107  Fifty Shades of Grey: Book One of the Fifty Sh...              E L James
# 106  Fifty Shades of Grey: Book One of the Fifty Sh...              E L James
# 132                         Go Set a Watchman: A Novel             Harper Lee
# 353                                 The Casual Vacancy           J.K. Rowling
#
#       UR   CR  Reviews  Price  Year        Genre     AR
# 545  4.9  545     9413      8  2019      Fiction  275.0
# 521  4.9  521     5956     11  2019  Non Fiction  263.0
# 489  4.9  489     8842     10  2019      Fiction  247.0
# 488  4.9  488     8842     10  2018      Fiction  246.4
# 487  4.9  487     8842     10  2017      Fiction  246.0
# ..   ...  ...      ...    ...   ...          ...    ...
# 22   3.9   22     6310     13  2013      Fiction   13.0
# 107  3.8  107    47265     14  2013      Fiction   55.4
# 106  3.8  106    47265     14  2012      Fiction   54.9
# 132  3.6  132    14982     19  2015      Fiction   67.8
# 353  3.3  353     9372     12  2012      Fiction  178.2
#
# [550 rows x 9 columns]
